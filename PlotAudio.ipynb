# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import sys
# %matplotlib notebook
import glob
import os
import time

fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
#ax2 = fig.add_subplot(212)
plt.ion()

fig.show()
fig.canvas.draw()

def get_latest_file():
    total_count = 0
    gun_count = 0
    for line in open("/Users/pranavlal/Documents/Big_Data/Project/dhishoom2/audio_clips.csv"):
        last=line
    sensor, dt, flag, prediction, fileName = last.split('|')
    return sensor, dt, flag, prediction, fileName[:-2]

while 1:
    ax.clear()
    sensor, dt, flag, prediction, fileName = get_latest_file()
    sr, wav_data = wavfile.read(fileName)
    Time=np.linspace(0, len(wav_data)/sr, num=len(wav_data))
    print flag
    if flag == '1':
        print "In gunshot"
        plt.suptitle("GUNSHOT DETECTED near " + sensor + " at " + dt, fontsize = 35)
        ax.set_title("Sound class:" + prediction, fontsize = 20)
        ax.plot(Time, wav_data, 'r-')
    else:
        print "Not in"
        plt.suptitle("No threats near " + sensor + " at " + dt, fontsize = 35)
        ax.set_title("Sound class:" + prediction, fontsize = 20)
        ax.plot(Time, wav_data, 'b-')
        #ax2.set_title("all good")
        #ax2.plot(Time, wav_data, 'b-')
    
    fig.canvas.draw()
    time.sleep(10)
# Out:
# <img src="data:image/png;base64,..." width="2000">
# 0
# Not in
# 0
# Not in
# 0
# Not in
# 0
# Not in
# 0
# Not in
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-24133015c1fb> in <module>()
#      44
#      45     fig.canvas.draw()
# ---> 46     time.sleep(10)
#      47
#      48
#
# KeyboardInterrupt:
